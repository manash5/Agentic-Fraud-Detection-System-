# %% [markdown]
# # Offline Fraud Detection Evaluation
#
# Computes precision, recall, F1, AUROC, and PR-AUC against `backend/datasets/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "eval" else Path.cwd()
sys.path.insert(0, str(ROOT))

from eval.offline_validation import evaluate, load_eval_frame

DATA_DIR = ROOT / "datasets"
y_true, y_score = load_eval_frame(DATA_DIR)
metrics = evaluate(y_true, y_score)
metrics
